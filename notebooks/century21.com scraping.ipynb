# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np
import re

# %%
def get_soup(url):
    
    headers = {
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
        'referrer': 'https://google.com',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-US,en;q=0.9',
        'Pragma': 'no-cache',
    }
    
    response = requests.get(url, headers=headers)
    results = response.content
    if not response.status_code == 404:
        soup = BeautifulSoup(results, 'lxml')
    return soup

# %%
url = 'https://www.century21.com/for-sale-homes/Boston-MA-1296c/propertytype_SFR,TOWNHOUSE,MFR'
soup = get_soup(url)

# %%
url1 = 'https://www.century21.com/property/37_39-Cunard-Street-Boston-MA-02120/M-72594151-MLSPIN/detail?src=list'
soup1 = get_soup(url1)

# %%
soup1.find('a')
# Out:
# <a name="ask"></a>

# %%
soup1
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
# <head>
# <title>37-39 Cunard Street, Boston, MA  — CENTURY 21 Real Estate</title>
# <meta content="This 20 bedroom, 6 bathroom Multi-Family for sale is located at 37-39 Cunard Street, Boston, MA 02120. View 16 photos, price history and more on century21.com." name="description"/>
# <meta content="37-39 Cunard Street, Boston, MA 02120, CENTURY 21 Real Estate, real estate, Boston real estate, 02120 real estate, homes for sale, recent home sales, property listings, home values, photos" name="keywords"/>
# <script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"692b4306b8",applicationID:"210614834"};window.NREUM||(NREUM={}),__nr_require=function(n,e,t){function r(t){if(!e[t]){var i=e[t]={exports:{}};n[t][0].call(i.exports,function(e){var i=n[t][1][e];return r(i||e)},i,i.exports)}return e[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<t.length;i++)r(t[i]);return r}({1:[function(n,e,t){function r(){}function i(n,e,t){return function(){return o(n,[u.now()].concat(f(arguments)),e?null:this,t),e?void 0:this}}var o=n("handle"),a=n(4),f=n(5),c=n("ee").get("tracer"),u=n("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],d="api-",l=d+"ixn-";a(p,function(n,e){s[e]=i(d+e,!0,"api")}),s.addPageAction=i(d+"addPageAction",!0),s.setCurrentRouteName=i(d+"routeName",!0),e.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(n,e){var t={},r=this,i="function"==typeof e;return o(l+"tracer",[u.now(),n,t],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],t),i)try{return e.apply(this,arguments)}catch(n){throw c.emit("fn-err",[arguments,this,n],t),n}finally{c.emit("fn-end",[u.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(n,e){m[e]=i(l+e)}),newrelic.noticeError=function(n,e){"string"==typeof n&&(n=new Error(n)),o("err",[n,u.now(),!1,e])}},{}],2:[function(n,e,t){function r(n,e){var t=n.getEntries();t.forEach(function(n){"first-paint"===n.name?a("timing",["fp",Math.floor(n.startTime)]):"first-contentful-paint"===n.name&&a("timing",["fcp",Math.floor(n.startTime)])})}function i(n){if(n instanceof c&&!s){var e,t=Math.round(n.timeStamp);e=t>1e12?Date.now()-t:f.now()-t,s=!0,a("timing",["fi",t,{type:n.type,fid:e}])}}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var o,a=n("handle"),f=n("loader"),c=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){o=new PerformanceObserver(r);try{o.observe({entryTypes:["paint"]})}catch(u){}}if("addEventListener"in document){var s=!1,p=["click","keydown","mousedown","pointerdown","touchstart"];p.forEach(function(n){document.addEventListener(n,i,!1)})}}},{}],3:[function(n,e,t){function r(n,e){if(!i)return!1;if(n!==i)return!1;if(!e)return!0;if(!o)return!1;for(var t=o.split("."),r=e.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}e.exports={agent:i,version:o,match:r}},{}],4:[function(n,e,t){function r(n,e){var t=[],r="",o=0;for(r in n)i.call(n,r)&&(t[o]=e(r,n[r]),o+=1);return t}var i=Object.prototype.hasOwnProperty;e.exports=r},{}],5:[function(n,e,t){function r(n,e,t){e||(e=0),"undefined"==typeof t&&(t=n?n.length:0);for(var r=-1,i=t-e||0,o=Array(i<0?0:i);++r<i;)o[r]=n[e+r];return o}e.exports=r},{}],6:[function(n,e,t){e.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(n,e,t){function r(){}function i(n){function e(n){return n&&n instanceof r?n:n?c(n,f,o):o()}function t(t,r,i,o){if(!d.aborted||o){n&&n(t,r,i);for(var a=e(i),f=v(t),c=f.length,u=0;u<c;u++)f[u].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function l(n,e){h[n]=v(n).concat(e)}function m(n,e){var t=h[n];if(t)for(var r=0;r<t.length;r++)t[r]===e&&t.splice(r,1)}function v(n){return h[n]||[]}function g(n){return p[n]=p[n]||i(t)}function w(n,e){u(n,function(n,t){e=e||"feature",y[t]=e,e in s||(s[e]=[])})}var h={},y={},b={on:l,addEventListener:l,removeEventListener:m,emit:t,get:g,listeners:v,context:e,buffer:w,abort:a,ab ...
# <!-- resc1: false -->
# <!-- resc2: false -->
# <!-- resc3: false -->
# <!-- resc4: false -->
# <!-- resc5: false -->
# <!-- resc6: false -->
# <!-- resc7: false -->
# <!-- resc8: false -->
# <!-- resc9: false -->
# <!-- resc10: false -->
# <!-- resc11: null -->
# <script>
#   var _shouldShowRernEnrollment = false;
#
# </script>
# <meta content="37-39 Cunard Street, Boston, MA  — CENTURY 21 Real Estate" property="og:title"/>
# <meta content="37-39 Cunard Street, Boston, MA  — CENTURY 21 Real Estate" property="twitter:title"/>
# <meta content="https://images-mls.static-ziprealty.com/images_mls/MLSPIN/72/59/41/72594151.jpg" property="og:image"/>
# <meta content="https://images-mls.static-ziprealty.com/images_mls/MLSPIN/72/59/41/72594151.jpg" property="twitter:image"/>
# <meta content="This 20 bedroom, 6 bathroom Multi-Family for sale is located at 37-39 Cunard Street, Boston, MA 02120. View 16 photos, price history and more on century21.com." property="og:description"/>
# <meta content="This 20 bedroom, 6 bathroom Multi-Family for sale is located at 37-39 Cunard Street, Boston, MA 02120. View 16 photos, price history and more on century21.com." property="twitter:description"/>
# <meta content="https://www.century21.com/property/37_39-Cunard-Street-Boston-MA-02120/M-72594151-MLSPIN/detail" property="og:url"/>
# <meta content="CENTURY 21 Real Estate" property="og:site_name"/>
# <meta content="place" property="og:type"/>
# <meta content="42.336806" property="og:latitude"/>
# <meta content="-71.086185" property="og:longitude"/>
# <meta content="37-39 Cunard Street" property="og:street-address"/>
# <meta content="Boston" property="og:locality"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="MA" property="og:region"/>
# <meta content="02120" property="og:postal-code"/>
# <meta content="USA" property="og:country-name"/>
# <meta content="358798910972873" property="fb:app_id"/>
# <meta content="place" property="twitter:card"/>
# <meta content="https://www.century21.com/property/37_39-Cunard-Street-Boston-MA-02120/M-72594151-MLSPIN/detail" property="twitter:url"/>
# <meta content="42.336806" property="house:location:latitude"/>
# <meta content="-71.086185" property="house:location:longitude"/>
# <meta content="37-39 Cunard Street" property="house:location:street_address"/>
# <meta content="Boston" property="house:location:locality"/>
# <meta content="MA" property="house:location:region"/>
# <meta content="02120" property="house:location:postal_code"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images.static-century21.com/z/20191108192240/images" rel="preconnect"/><link href="https://images.static-century21.com/z/20191108192240/images" rel="dns-prefetch"/><link crossorigin="" href="https://css.static-century21.com/z/20191108192240/css" rel="preconnect"/><link href="https://css.static-century21.com/z/20191108192240/css" rel="dns-prefetch"/><link crossorigin="" href="https://js.static-century21.com/z/20191108192240/js" rel="preconnect"/><link href="https://js.static-century21.com/z/20191108192240/js" rel="dns-prefetch"/><link crossorigin="" href="https://images-mls.static-ziprealty.com" rel="preconnect"/><link href="https://images-mls.static-ziprealty.com" rel="dns-prefetch"/><link crossorigin="" href="https://fonts.googleapis.com" rel="preconnect"/><link href="https://fonts.googleapis.com" rel="dns-prefetch"/><link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://fonts.gstatic.com" rel="dns-prefetch"/>
# <link href="https://images.static-century21.com/z/20191108192240/images/platform/c21/mobile/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="https://images.static-century21.com/z/20191108192240/images/platform/c21/mobile/apple-touch-icon.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://images.static-century21.com/z/20191108192240/images/platform/c21/mobile/apple-touch-icon.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="https://images.static-century21.com/z/20191108192240/images/platform/c21/mobile/apple-touch-icon-iphone-retina-120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://images.static-century21.com/z/20191108192240/images/platform/c21/mobile/apple-touch-icon-ipad-retina-152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <meta content="s-EVXxXN5I3Scd5ewvbAZY-lgdiAFfe48WEbDbrcfX4" name="google-site-verification"/>
# <meta content="03162BEE012B212411A66A12E4B087F0" name="msvalidate.01"/>
# <style type="text/css">
# /* Font Icon Definitions */
# @font-face {
#   font-family: "zip-icons";
#   src:url("https://images.static-century21.com/z/20191108192240/images/fonts/zip-icons.eot");
#   src:url("https://images.static-century21.com/z/20191108192240/images/fonts/zip-icons.eot?#iefix") format("embedded-opentype"),
#   url("https://images.static-century21.com/z/20191108192240/images/fonts/zip-icons.woff") format("woff"),
#   url("https://images.static-century21.com/z/20191108192240/images/fonts/zip-icons.ttf") format("truetype"),
#   url("https://images.static-century21.com/z/20191108192240/images/fonts/zip-icons.svg#zip-icons") format("svg");
#   font-weight: normal;
#   font-style: normal;
# }
# </style>
# <script type="text/javascript">
#   window.fontsToLoad = {};
#   var googleFonts = [];
#
#     window.fontsToLoad.custom = {
#       families: ['Typold', 'TypoldCondenced', 'Oakes', 'BarlowSemiCondensed']
#     }
#
#
#
#
#   if( sessionStorage.foutFontsLoaded && googleFonts.length > 0) {
#     var head = document.head;
#     var link = document.createElement('link');
#     link.type = 'text/css';
#     link.rel = 'stylesheet';
#     link.href = '//fonts.googleapis.com/css?family=' + googleFonts;
#     head.appendChild(link);
#   }
#   if( sessionStorage.foutFontsLoaded) {
#     document.documentElement.className += " fonts-loaded";
#   }
#   if(googleFonts.length > 0){
#     window.fontsToLoad.google = {
#       families: googleFonts
#     };
#   }
# </script>
# <style type="text/css">
#   @font-face {
#     font-family: 'Oakes';
#     src: url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/oakes-regular/oakes-regular.woff2') format('woff2'),
#       url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/oakes-regular/oakes-regular.woff') format('woff');
#     font-weight: normal;
#     font-style: normal;
#   }
#   @font-face {
#     font-family: 'Oakes';
#     src: url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/oakes-bold/oakes-bold.woff2') format('woff2'),
#       url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/oakes-bold/oakes-bold.woff') format('woff');
#     font-weight: bold;
#     font-style: normal;
#   }
#   @font-face {
#     font-family: 'Oakes';
#     url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/oakes-medium/oakes-medium.woff2') format('woff2'),
#     url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/oakes-medium/oakes-medium.woff') format('woff');
#     font-weight: 300;
#     font-style: normal;
#   }
#   @font-face {
#     font-family: 'Oakes';
#     src: url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/oakes-regular-italic/oakes-regular-italic.woff2') format('woff2'),
#       url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/oakes-regular-italic/oakes-regular-italic.woff') format('woff');
#     font-weight: normal;
#     font-style: italic;
#   }
#
#   @font-face {
#     font-family: 'Typold';
#     src: url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/typold-regular/Typold-Regular.woff2') format('woff2'),
#       url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/typold-regular/Typold-Regular.woff') format('woff');
#     font-weight: normal;
#     font-style: normal;
#   }
#
#   @font-face {
#     font-family: 'Typold';
#     src: url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/typold-book-500/Typold-Book500.woff2') format('woff2'),
#       url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/typold-book-500/Typold-Book500.woff') format('woff');
#     font-weight: 500;
#     font-style: normal;
#   }
#
#    @font-face {
#       font-family: 'TypoldCondenced';
#       src: url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/typold-condenced-book/TypoldCondensed-Book.woff2') format('woff2'),
#         url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/typold-condenced-book/TypoldCondensed-Book.woff') format('woff');
#       font-weight: 300;
#       font-style: normal;
#     }
#
#   @font-face {
#     font-family: 'BarlowSemiCondensed';
#     src: url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/barlow-semi-condensed-medium/BarlowSemiCondensed-Medium.woff2') format('woff2'),
#       url('https://images.static-century21.com/z/20191108192240/images/fonts/c21/barlow-semi-condensed-medium/BarlowSemiCondensed-Medium.woff') format('woff');
#     font-weight: normal;
# 		font-style: normal;
#   }
# </style>
# <link href="https://css.static-century21.com/z/20191108192240/css/global-all.css" rel="stylesheet" type="text/css"/>
# <link href="https://css.static-century21.com/z/20191108192240/css/theme_c21.css" rel="stylesheet" type="text/css"/>
# <link href="https://images.static-century21.com/z/20191108192240/images/platform/c21/favicon.ico" rel="shortcut icon"/>
# <link href="https://css.static-century21.com/z/20191108192240/css/home-detail-all.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#
#
#   ga('create', 'UA-49853134-13', 'auto');
#
#   ga('require', 'displayfeatures');
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </script>
# <script type="text/javascript">
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   document.addEventListener('DOMContentLoaded',function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#                '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#
#
#
#   });
# </script>
# <!-- Global site tag (gtag.js) - Google AdWords: Other brands - 943015926, ZipRealty - 1064420760, ERA - DC-6356050 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-943015926"></script>
# <script>
#   var gtagId = 'AW-943015926';
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', gtagId);
# </script>
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#       n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window,document,'script',
#       'https://connect.facebook.net/en_US/fbevents.js');
#
#     fbq('init', '625197678005881');
#     fbq('track', 'PageView');
#
# </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=625197678005881&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <script type="text/javascript">
# _linkedin_partner_id = "1606737";
# window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || [];
# window._linkedin_data_partner_ids.push(_linkedin_partner_id);
# </script><script type="text/javascript">
#   (function(){var s = document.getElementsByTagName("script")[0];
#     var b = document.createElement("script");
#     b.type = "text/javascript";b.async = true;
#     b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
#     s.parentNode.insertBefore(b, s);})();
# </script>
# <noscript>
# <img alt="" height="1" src="https://px.ads.linkedin.com/collect/?pid=1606737&amp;fmt=gif" style="display:none;" width="1"/>
# </noscript>
# <script>
#   window.showMobileOptimized = false;
# </script>
# <script src="https://js.static-century21.com/z/20191108192240/js/modules/splitioRunner.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   window._API_HOST = 'api.zaplabs.com';
#   var _XHR_URL_PREFIX = '/xhr';
#   var _XHR_URI_PREFIX = '/xhr';
#   var _JSP_URL_PREFIX = '';
#   var _JSP_STATIC_URL_PREFIX = 'https://www.century21.com/z/20191108192240';
#   var _TILES_URL_PREFIX = '';
#   var _IMG_URL_PREFIX = 'https://images.static-century21.com/z/20191108192240/images';
#   var _IMG_MLS_URL_PREFIX = 'https://images-mls.static-ziprealty.com';
#   var _PROD_DOMAIN_WITHOUT_SUMDOMAIN = 'century21.com';
#   var _IS_PRODUCTION = true
#
#   var _GOOGLE_MAPS_CLIENT_ID = 'gme-nrtllc';
#   var _PRIMARY_COLOR = '#BEAF87';
#
#   var _HEAD = document.getElementsByTagName('head')[0];
#
#   var addBofALeadGenElement = null;
#   var _APPLICATION_ID = '8';
#   var _isUsaaBranded = false;
#
#
#     window._METRO_LATITUDE = 42.37;
#     window._METRO_LONGITUDE = -71.03;
#
#
#   var _USER_LOGGED_IN = false;
#
#
#   var _AGENT_LOGGED_IN = false;
#
#
#   var _USER_CURRENT_METRO = 'boston';
#
#   if(!_USER_CURRENT_METRO || _USER_CURRENT_METRO == 'null') {
#     _USER_CURRENT_METRO = 'null';
#   }
# </script>
# <script src="https://js.static-century21.com/js/yui/yui-2.9.0/yahoo-dom-event/yahoo-dom-event.js" type="text/javascript"></script>
# <script src="https://js.static-century21.com/z/20191108192240/js/v2/ziprealty-core.js" type="text/javascript"></script>
# <style type="text/css">
#     #pgHomeDetail .zoom-cont #zoom-in:hover, .zoom-cont #zoom-out:hover {
#       color: #BEAF87;
#     }
#   </style>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# </head>
# <body id="pgHomeDetail">
# <a name="ask"></a><a name="visit"></a><a name="share"></a><a name="listingappt"></a>
# <div id="hd">
# <script>
#   function extLink(link, cat, label) {
#     event.preventDefault();
#     ga('send', 'event', 'Outbound Link', cat, label);
#     window.open(link,'_blank','height=750,width=1150,resizable=1,toolbar=0,scrollbars=1');
#   }
# </script>
# <div class="js-insert-menu" id="hdr-module">
# <zap-header data-agent-id="0" data-brand-id="8" data-buy-link="/home-buying-advice" data-company-id="2110" data-company-name="CENTURY 21 Cityside" data-company-state="MA" data-drupal-url="https://cms.zaplabs.com" data-has-agent="false" data-live-chat="" data-phone="617.262.2600" data-retrieve-state="true" data-sell-link="/home-selling-advice" data-show-custom-pages="true" data-team="false" data-team-name="" data-team-url="">
# <header class="outbound-container">
# <ul class="outbound-header"></ul>
# </header>
# <div class="header-container">
# <div class="logo-container logo-container--zip">
# </div>
# <div class="hamburger-container d-none">
# <svg>
# <rect height="1.5" id="Rectangle-21" width="20.015444" x="0" y="0"></rect>
# <rect height="1.5" id="Rectangle-21" width="20.015444" x="0" y="7"></rect>
# <rect height="1.5" id="Rectangle-21" width="20.015444" x="0" y="14"></rect>
# </svg>
# </div>
# <div class="menu-container">
# <div class="menu-list-container">
# <nav class="menu-list">
# <zap-dropdown datareceived="true">
# <span class="menu-item parent">
# <a href="/home-buying-advice">Buy</a>
# </span>
# </zap-dropdown>
# <zap-dropdown datareceived="true">
# <span class="menu-item parent">
# <a href="/home-selling-advice">Sell</a>
# <ul class="submenu-container">
# <li class="menu-item submenu">
# <a href="/home-value-estimates">Home Value Estimate</a>
# </li>
# </ul>
# </span>
# </zap-dropdown>
# <zap-dropdown datareceived="true">
# <span class="menu-item parent">
# <a href="/real-estate-agents">Find an Agent</a>
# </span>
# </zap-dropdown>
# <zap-dropdown datareceived="true">
# <span class="menu-item parent">
# <a href="https://careers.century21.com/">Join</a>
# </span>
# </zap-dropdown>
# </nav>
# </div>
# </div>
# </div>
# </zap-header>
# <div id="hdr-search">
# <div class="l-semifluid nomw">
# <form action="https://www.century21.com/homes/for-sale/search/locate" class="form-std" id="psb_desktop" method="POST" name="searchForm">
# <input id="didUseAutocomplete" name="didUseAutocomplete" type="hidden" value="false"/>
# <input name="changeLocation" type="hidden" value="0"/>
# <input name="searchFormType" type="hidden" value="city"/>
# <input name="originalLocation" type="hidden" value="Boston, MA"/>
# <input name="view" type="hidden" value=""/>
# <input name="doSubmit" type="hidden" value="true"/>
# <input name="results_per_page" type="hidden" value="15"/>
# <input name="sort" type="hidden" value="date_desc"/>
# <input name="polygon" type="hidden" value=""/>
# <input name="latitude_min" type="hidden" value=""/>
# <input name="latitude_max" type="hidden" value=""/>
# <input name="longitude_min" type="hidden" value=""/>
# <input name="longitude_max" type="hidden" value=""/>
# <input name="lat" type="hidden" value=""/>
# <input name="lon" type="hidden" value=""/>
# <input name="zoomLevel" type="hidden" value=""/>
# <div class="cs-drop-downs" id="main-search-cont">
# <div id="searchInputSection">
# <label class="ada-label" for="inputZipCode">SEARCH FOR HOMES</label>
# <zap-input aria-label="Search by city, neighborhood, zip code or MLS number" autocomplete="off" class="autocomplete-zap-input js-desktop-autocomplete-field" data-company-id="2110" describedby="box-error-msg" icon="mag" id-combobox-results="desktop-combobox-results" input-id="inputZipCode" maxlength="60" name="location" placeholder="Enter city, neighborhood, ZIP, address, or MLS #" size="60" type="text" value="Boston, MA">
# </zap-input>
# <div class="clear-icon-container" id="clearInputIconContainer">
# <button aria-label="Clear search. (Pressing enter or spacebar key to clear search criteria)" id="clearInputIcon" type="reset"></button>
# </div>
# <div id="search-tip">Enter a city, neighborhood, school district, address or MLS#</div>
# </div>
# <span class="cs-range-container show-scrollbar-webkit">
# <label class="ada-label" for="price">PRICE</label>
# <zap-range-selector data-accepts-input="money" data-default-max="999999999" data-default-min="0" data-max-form-name="listing_price_max" data-max-placeholder="Max Price" data-min-form-name="listing_price_min" data-min-placeholder="Min Price" data-short-field-name="Price" id="price">
# <zap-range-selector-value data-int-value="50000" data-text-value="$50,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="75000" data-text-value="$75,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="100000" data-text-value="$100,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="110000" data-text-value="$110,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="120000" data-text-value="$120,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="130000" data-text-value="$130,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="140000" data-text-value="$140,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="150000" data-text-value="$150,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="160000" data-text-value="$160,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="170000" data-text-value="$170,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="180000" data-text-value="$180,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="190000" data-text-value="$190,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="200000" data-text-value="$200,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="225000" data-text-value="$225,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="250000" data-text-value="$250,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="275000" data-text-value="$275,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="300000" data-text-value="$300,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="325000" data-text-value="$325,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="350000" data-text-value="$350,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="375000" data-text-value="$375,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="400000" data-text-value="$400,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="425000" data-text-value="$425,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="450000" data-text-value="$450,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="475000" data-text-value="$475,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="500000" data-text-value="$500,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="525000" data-text-value="$525,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="550000" data-text-value="$550,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="575000" data-text-value="$575,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="600000" data-text-value="$600,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="650000" data-text-value="$650,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="700000" data-text-value="$700,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="750000" data-text-value="$750,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="800000" data-text-value="$800,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="850000" data-text-value="$850,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="900000" data-text-value="$900,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="1000000" data-text-value="$1,000,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="1250000" data-text-value="$1,250,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="1500000" data-text-value="$1,500,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="1750000" data-text-value="$1,750,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="2000000" data-text-value="$2,000,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="2250000" data-text-value="$2,250,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="2500000" data-text-value="$2,500,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="2750000" data-text-value="$2,750,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="3000000" data-text-value="$3,000,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="4000000" data-text-value="$4,000,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="5000000" data-text-value="$5,000,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="6000000" data-text-value="$6,000,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="7000000" data-text-value="$7,000,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="8000000" data-text-value="$8,000,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="9000000" data-text-value="$9,000,000"></zap-range-selector-value>
# <zap-range-selector-value data-int-value="10000000" data-text-value="$10,000,000"></zap-range-selector-value>
# </zap-range-selector>
# </span>
# <span class="cs-select-container--tiny">
# <label class="ada-label" id="zap-select-beds-label">BEDS</label>
# <zap-select data-labelled-by="zap-select-beds-label" id="beds" name="min_bedrooms">
# <zap-option value="">Any</zap-option>
# <zap-option value="1">1+ Beds</zap-option>
# <zap-option value="2">2+ Beds</zap-option>
# <zap-option value="3">3+ Beds</zap-option>
# <zap-option value="4">4+ Beds</zap-option>
# <zap-option value="5">5+ Beds</zap-option>
# </zap-select>
# </span>
# <span class="cs-select-container--tiny">
# <label class="ada-label" id="zap-select-baths-label">BATHS</label>
# <zap-select aria-label="Baths" class="primaryField" data-labelled-by="zap-select-baths-label" id="baths" name="min_full_baths">
# <zap-option value="">Any</zap-option>
# <zap-option value="1">1+ Baths</zap-option>
# <zap-option value="2">2+ Baths</zap-option>
# <zap-option value="3">3+ Baths</zap-option>
# <zap-option value="4">4+ Baths</zap-option>
# </zap-select>
# </span>
# <button aria-controls="advanced-search-cont" aria-expanded="false" class="btn-primary btn-primary--expand js-advanced-search-trigger" id="advanced-search-link"><span>More Filters</span>
# <svg class="icon icon--dropdown-carrot icon-caret--down" height="7" viewbox="0 0 9.7667 6.7638" width="9">
# <title>Dropdown Caret</title>
# <path d="M5.5819,6.4285,9.5683,1.4552A.8953.8953,0,0,0,8.87,0H.8969A.8953.8953,0,0,0,.1984,1.4552L4.1848,6.4285A.8953.8953,0,0,0,5.5819,6.4285Z"></path>
# </svg>
# </button>
# <button class="btn-primary btn-primary--input btn-primary--search btn-primary--globalsearch brand-colored--button" id="brand-search-home" name="submitbtn" type="submit" value="Search">
# <span><i aria-hidden="true" class="f-icon f-icon-mob-search font-17"></i> Search C21</span>
# </button>
# <svg height="0" width="0">
# <defs>
# <clippath id="svgPathCut">
# <polygon points="5,0 10,5 0,5 5,0" xmlns="http://www.w3.org/2000/svg"></polygon>
# </clippath>
# </defs>
# </svg>
# </div>
# <zap-advanced-search-panel data-company-id="2110" data-is-agent="false" data-location-types="CITY,NEIGHBORHOOD,SUBDIVISION,SCHOOL_DISTRICT,ZIP_CODE,ADDRESS,MLS_NUMBER,SCHOOL,POINT_OF_INTEREST,COUNTY" data-optional='{"surveyHidden":"true","mlsLongnames":"","mlsSource":"","personnelId":""}' data-url-field="">
# <div class="slider--closed show-scrollbar-webkit" id="advanced-search-cont"></div>
# </zap-advanced-search-panel>
# </form>
# </div>
# </div>
# <div class="autocompleteFormSearchResults" id="hdr-search-mobile">
# <form action="/homes/for-sale/search/locate" class="js-autocomplete-form" method="POST">
# <input autocomplete="off" class="searchResults-autoComplete js-mobile-autocomplete-field" data-company-id="2110" id-combobox-results="mobile-combobox-results" name="location" placeholder="City, neighborhood, ZIP, address, or MLS #" type="text" value="Boston, MA"/>
# <a aria-expanded="false" class="js-filters search-filters-link" data-panel-event-category="sr-filter-btn" data-panel-event-label="search_filter" href="/mobile/fragments/filters.jsp" id="searchBtn" tabindex="0" title="Search">
#     Filter
#     </a>
# </form>
# </div>
# </div>
# </div>
# <main>
# <div class="homedetailpage" id="bd">
# <div class="l-semifluid">
# <div>
# <ul aria-label="breadcrumbs" class="li-h li-h--breadcrumb li-h--inline" role="region">
# <li itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a class="js-lux-breadcrumb" href="/" itemprop="url"><span itemprop="title">Homes For Sale</span></a></li>
# <li itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/century-21-cityside-2110c" itemprop="url"><span itemprop="title">CENTURY 21 Cityside</span></a></li>
# <li itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/for-sale-homes/Boston-MA-1296c" itemprop="url"><span itemprop="title">Boston, MA</span></a></li>
# <li itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/for-sale-homes/Lower-Roxbury-Boston-MA-21503n" itemprop="url"><span itemprop="title">Lower Roxbury</span></a></li>
# </ul>
# </div>
# <div class="l-semiflex">
# <div class="l-semiflex__main">
# <div class="pod pod--rounded iez2" itemscope="" itemtype="http://schema.org/Residence">
# <meta content="Find information about 37-39 Cunard Street, Boston, MA 02120, including photos, home values, property information, MLS data, and more on century21.com" itemprop="description"/>
# <div itemprop="geo" itemscope="" itemtype="http://schema.org/GeoCoordinates">
# <meta content="42.336806" itemprop="latitude"/>
# <meta content="-71.086185" itemprop="longitude"/>
# </div>
# <div class="cf" id="propInfoWrapper">
# <div class="f-left" id="pdCol" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress" tabindex="0">
# <h1 class="ib font-24 mb-10 mt-0 font-normal" itemprop="streetAddress">
#   37-39 Cunard Street
#
# </h1>
# <i class="icon-text icon-text--new ml-5 tooltip tooltip--onhover tooltip--icon tooltip--right" id="newlyListedIcon" style="vertical-align: text-bottom; margin: 2px 0" title="New - Listed in the last 3 days">
#     NEW
#
#   </i>
# <br/>
# <div class="ib font-14 mt-0 mb-0 font-normal js-prop-address">
# <span itemprop="addressLocality">Boston</span>, <span itemprop="addressRegion">MA</span>
# <span itemprop="postalCode">02120</span>
# </div>
# <div class="mb-10">
# <span class="font-subtler">
# <i class="icon--nhood icon-std-spacing"></i><span class="mr-10" title="Neighborhood: Lower Roxbury">Lower Roxbury</span>
# <i class="icon--sd icon-std-spacing"></i><span class="mr-10" title="Boston School District">Boston School District</span>
# </span>
# </div>
# <div class="prop-details">
# <ul role="list">
# <li class="val left is-first">
#       20
#       <span class="label right"> bed</span>
# </li>
# <li class="val left">
#       6
#       <span class="label right"> bath</span>
# </li>
# <li class="val left">
#       6,672
#       <span class="label right"> sq ft</span>
# </li>
# <li class="val left">
#       $787
#       <span class="label right"> / sq ft</span>
# </li>
# <li class="val standalone">
#       MFR <br/>
# </li>
# <li class="label left is-first">
#       Lot Size
#       <span class="val middle">3,078</span>
# <span class="label right">sq ft</span>
# </li>
# <li class="label left">
#       On site
#       <span class="val middle"> 2 </span>
# <span class="label right"> days</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="f-right t-right" id="hdPriceCont">
# <div class="font-price" itemscope="" itemtype="http://schema.org/Product">
# <meta content="37-39 Cunard Street, Boston, MA 02120 - MLS #72594151" itemprop="name"/>
# <meta content="37-39 Cunard Street is a 6-unit multifamily offering located in the heart of Boston. This exceptional offering consists of two, three-family buildings adjacent to each other and features a mix of three and four bedroom apartments. Its proximity to the South End, Longwood Medical Area (LMA) and various prominent colleges and universities make these properties extremely desirable. 37-39 Cunard Street presents the rare opportunity to own generational assets with immediate value-add potential in a world-class neighborhood." itemprop="description"/>
# <meta content="https://www.century21.com/property/37_39-Cunard-Street-Boston-MA-02120/M-72594151-MLSPIN/detail" itemprop="url"/>
# <meta content="https://images-mls.static-ziprealty.com/images_mls/MLSPIN/72/59/41/72594151.jpg" itemprop="image"/>
# <div itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="USD" itemprop="priceCurrency"/>
# <span class="ls-hd" tabindex="0"> <span class="font-16 mr-10">For Sale:</span><span class="font-24" itemprop="price">$5,250,000</span></span>
# </div>
# </div>
# <div class="mb-10">
# <zap-popover data-content-target="tooltip1" data-tippy-interactive="true" data-tippy-placement="bottom-end" data-tippy-theme="zap-longisland">
# <a aria-label="$20,489/mo. Click to go to the mortgage calculator on this same page" aria-labelledby="tooltip1" class="js-ada-tooltip mortgage-tooltip ib" href="/property/link/M-72594151-MLSPIN/detail#mortgagecalc" id="tippy1">
#                       $20,489/mo
#                     </a>
# </zap-popover>
# <div class="tippy-hide" id="tooltip1" role="tooltip">
# <div class="l-grid cf">
# <div class="l-grid__col-4-5 f-left font-000 mb-5">
# <strong>Monthly Payment:</strong>
# </div>
# <div class="l-grid__col-1-5 f-right t-right font-000">
# <strong>$20,489</strong>
# </div>
# </div>
# <div class="l-grid cf">
# <div class="l-grid__col-4-5 f-left font-666 mb-5">
#       Principal &amp; Interest:
#     </div>
# <div class="l-grid__col-1-5 f-right t-right font-666">
#
#       $20,489
#     </div>
# </div>
# <div class="l-grid cf">
# <div class="l-grid__col-4-5 f-left font-666 mb-5">
#       HOA Dues:
#     </div>
# <div class="l-grid__col-1-5 f-right t-right font-666">
#       $0
#     </div>
# </div>
# <div class="font-disclaimer t-center pt-10 pb-10">
#     (Based on a 30 year fixed loan at 4.18% with $1,050,000 down)
#   </div>
# <div class="t-center pt-1r mortgage-tooltip-calc-division">
# <a href="javascript:void(0)" onclick="smoothScroll('mortgagecalc', '#mortgage-calc-div h2');" title="Mortgage calculator">Mortgage Calculator</a>
# </div>
# </div>
# </div>
# <a class="btn-primary btn-primary--input btn-primary--large js-modals" data-title="Request Tour" href="/ac/boston/home_detail/cf_request_showing/pre_log/invoke.jsp?addressId=M-72594151-MLSPIN&amp;mlsNumber=72594151&amp;mlsSource=MLSPIN&amp;cta_location=hd-top&amp;bmd_company_id=2110" rel="nofollow">
#                   Request a Showing
#                 </a>
# </div>
# <div id="hdCTA"></div>
# </div>
# <div class="mt-20">
# </div>
# <div class="fRight inlineBlock hd-social-cont">
# <span>Share:</span>
# <ul class="li-h li-h--inline ulSocial">
# <li><a aria-label="Share via Facebook" class="fb" href="http://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.century21.com%2Fproperty%2F37_39-Cunard-Street-Boston-MA-02120%2FM-72594151-MLSPIN%2Fdetail%3Futm_source%3Dfacebook%26utm_medium%3Dsocial%26utm_content%3Dhome%26referredByCompany%3D2110" onclick="return logFacebookShare(this.href, 'hd')" target="_blank"></a>
# </li>
# <li><a aria-label="Share via Email" class="email js-modals" href="/ac/boston/home_detail/rf_email_friend/pre_log/invoke.jsp?mlsNumber=72594151&amp;mlsSource=MLSPIN&amp;addressId=M-72594151-MLSPIN&amp;cta_location=hd-top&amp;referredByCompany=2110" title="Email"></a>
# </li>
# </ul>
# </div>
# <ul class="li-h li-h--tabbed-b li-h--tabbed-b--underline li-h--tabbed-b--large li-h--tabbed-b--wide" id="hdMapNavNew" role="tablist" style="margin-bottom: 20px;">
# <li class="active" id="jsPhotoViewTab"><a aria-controls="pvCont" aria-label="Photos" aria-selected="true" href="#" role="tab" tabindex="0" title="Photos for 37-39 Cunard Street">Photos</a></li>
# <li id="jsMapsTab"><a aria-controls="bingMapDiv" aria-label="Maps" aria-selected="false" href="#" role="tab" tabindex="-1" title="Maps for 37-39 Cunard Street">Maps</a></li>
# <li id="jsBirdsEyeView"><a aria-controls="birdseyeMapDiv" aria-label="Bird's Eye" aria-selected="false" href="#" role="tab" tabindex="-1" title="Bird's Eye View">Bird's Eye</a></li>
# <li id="jsStreetView"><a aria-controls="googleMapDiv" aria-label="Street View" aria-selected="false" href="#" role="tab" tabindex="-1" title="Street View">Street View</a></li>
# </ul>
# <div aria-label="Carousel" id="pvCont" itemprop="image" itemscope="" itemtype="http://schema.org/ImageObject" role="region">
# <meta content="https://www.century21.com/property/link/M-72594151-MLSPIN/detail" itemprop="url"/>
# <meta content="https://images-mls.static-ziprealty.com/images_mls/MLSPIN/72/59/41/72594151.jpg" itemprop="contentUrl"/>
# <a class="js-save-property-heart js-modals icon-initial-hide icon--save-overlay--pos favorite-heart-icon" data-client-id="null" data-event-label="hd-middle" data-home-id="" data-logged-in-as="" data-logged-in-url="/xhr/saveHome?cxp=0&amp;mlsNumber=72594151&amp;mlsSource=MLSPIN&amp;metroName=boston&amp;companyId=2110" data-logged-out-url="/ac/boston/home_detail/rf_save_home/pre_log/invoke.jsp?cta_location=hd-middle&amp;bmd_company_id=2110&amp;mlsNumber=72594151&amp;mlsSource=MLSPIN" data-mlsnum="72594151" data-mlssource="MLSPIN" data-property-id="72594151" data-saved-home="false" data-title="Save Home" href="#">
# <svg aria-hidden="false" aria-labelledby="svg-title" class="icon icon--heart-full icon--save-overlay icon--inactive-with-stroke" role="img">
# <title class="sr-only" id="svg-title">Login to save this home</title>
# <desc class="sr-only">Click the heart icon to add this property to your favorites list</desc>
# <use xlink:href="https://www.century21.com/z/20191108192240/images/icons/svg/symbol-defs.svg#icon--heart-full"></use>
# </svg>
# </a>
# <div class="photobox js-photoGallery" data-disable-overlay="false" data-frame="/property/link/M-72594151-MLSPIN/photos_overlay" data-photo-address="37-39 Cunard Street, Boston, MA 02120" data-photo-domain="https://images-mls.static-ziprealty.com" data-photoset="/xhr/homes/photos/all?photoId=72594151&amp;photoSource=MLSPIN&amp;inactive=false">
# <img class="initialImage" src="https://images-mls.static-ziprealty.com/images_mls/MLSPIN/72/59/41/72594151.jpg"/>
# </div>
# </div>
# <div aria-label="map" class="dispNone p-relative" id="bingMapDiv" role="region" style="z-index:1">
# <div id="mapContainer" style="position: relative; overflow:hidden;">
# <div id="mapDiv" style="top:0; right:0; position: relative; width:100%; height: 446px;"></div>
# <div class="map-pod map-pod--bubble school-bubble cf" id="schoolBubble">
# <div class="mb-10">
# <a class="font-bold" href="#" id="bubbleLink" style="margin-right: 20px" target="_top" title="Bubble"><span id="bubbleName" style="font-weight: bold;"></span></a>
# <div class="pod__map-overlay-close" id="schoolExitBubble"></div>
# </div>
# <div class="f-left">
# <div id="bubbleAddress"></div>
# <div class="font-12">
# <span id="bubbleCity"></span>,
#       <span id="bubbleState"></span> <span id="bubbleZip"></span>
# </div>
# <div id="bubblePhone"></div>
# <div class="font-bold" id="bubbleDistance"></div>
# <div class="font-11 mt-5">
# <span class="font-bold" id="bubbleStudents"></span> students, <span class="font-bold" id="bubbleRatio"></span> students per teacher
#     </div>
# </div><!-- end: f-left -->
# <div class="f-right">
# <div id="school-score"></div>
# </div><!-- end: f-right -->
# </div>
# <div class="map-pod map-pod--bubble cf" id="bizBubble">
# <span id="bizExitbubble"><img alt="Close" src="https://images.static-century21.com/z/20191108192240/images/map/close_window.gif"/></span>
# <span id="yelpBubbleContent"> </span>
# </div>
# <div class="map-pod map-pod--bubble cf" id="ps_bubble">
# <div class="t-center mb-10">
# <a class="font-bold" href="#" id="ps_address1link" title="Address">
# <b><span id="ps_address1"></span><span id="ps_address2"></span></b>
# </a>
# <div class="pod__map-overlay-close" id="ps_exitbubble"></div>
# </div>
# <table width="300">
# <tr>
# <td>
# <table class="soldb-table" style="background-color: #FFF">
# <tr>
# <td class="soldb-label">
#                               Bed:
#                             </td>
# <td>
# <span id="ps_beds"></span>
# </td>
# <td class="soldb-label">
#                               Property Type:
#                             </td>
# <td>
# <span id="ps_property_type"></span>
# </td>
# </tr>
# <tr>
# <td class="soldb-label">
#                               Bath:
#                             </td>
# <td>
# <span id="ps_baths"></span>
# </td>
# <td class="soldb-label">
#                               Sold Price:
#                             </td>
# <td>
# <span class="font-price" id="ps_soldPrice"></span>
# </td>
# </tr>
# <tr>
# <td class="soldb-label">
#                               Sq. Ft.:
#                             </td>
# <td>
# <span id="ps_sqft"></span>
# </td>
# <td class="soldb-label">
#                               Sold Date:
#                             </td>
# <td>
# <span id="ps_soldDate"></span>
# </td>
# </tr>
# <tr>
# <td class="soldb-label">
#                               Lot Size:
#                             </td>
# <td>
# <span id="ps_lot_size"></span>
# </td>
# <td class="soldb-label">
#                               APN:
#                             </td>
# <td>
# <span id="ps_apn"></span>
# </td>
# </tr>
# <tr>
# <td class="soldb-label">
#                               Year Built:
#                             </td>
# <td>
# <span id="ps_year_built"></span>
# </td>
# <td class="soldb-label">
#                               FIPS:
#                             </td>
# <td>
# <span id="ps_fips"></span>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td bgcolor="#FFFFFF">
# <table>
# <tr>
# <td style="padding: 10px">
# <a href="#" id="ps_avm_link" style="font-size: 85%;" title="View All Estimates For This Home">View All Estimates For This Home</a><br/>
# <a href="#" id="ps_ipt_link" style="font-size: 85%;" title="Use Our Interactive Pricing Tool">Use Our Interactive Pricing Tool</a><br/>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </div>
# <div class="map-pod map-pod--bubble cf" id="soldHomeBubble">
# <span id="soldHomeExitBubble"><img alt="close" src="https://images.static-century21.com/z/20191108192240/images/map/close_window.gif"/></span>
# <table style="margin-bottom: 10px" width="100%">
# <tr>
# <td class="t-center">
# <a href="#" id="sh_link" target="_top" title="Sold home"><span id="sh_address1_link"></span></a>
# <span id="sh_address1"></span>
# <br/><span id="sh_address2"></span>
# </td>
# </tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td class="leftCol">
#                         Sold Price:<br/>
# </td>
# <td>
# <span id="sh_price"></span>
# </td>
# </tr>
# <tr>
# <td class="leftCol">
#                         Date Sold:<br/>
# </td>
# <td>
# <span id="sh_date_sold"></span>
# </td>
# </tr>
# <tr>
# <td class="leftCol">
#                         Beds:<br/>
# </td>
# <td>
# <span id="sh_beds"></span>
# </td>
# </tr>
# <tr>
# <td class="leftCol">
#                         Baths:<br/>
# </td>
# <td>
# <span id="sh_baths"></span>
# </td>
# </tr>
# <tr>
# <td class="leftCol">
#                         Sq. Ft.:<br/>
# </td>
# <td>
# <span id="sh_sqft"></span>
# </td>
# </tr>
# <tr>
# <td class="leftCol">
#                         Lot Size:<br/>
# </td>
# <td>
# <span id="sh_lotsize"></span>
# </td>
# </tr>
# <tr>
# <td class="leftCol">
#                         Property Type:<br/>
# </td>
# <td>
# <span id="sh_ptype"></span>
# </td>
# </tr>
# <tr style="display: none">
# <td class="leftCol">
#                         Year Built:<br/>
# </td>
# <td>
# <span id="sh_year_built"></span>
# </td>
# </tr>
# <tr>
# <td class="leftCol">
#                         Price/Sq.Ft.:<br/>
# </td>
# <td>
# <span id="sh_priceSqFt"></span>
# </td>
# </tr>
# <tr id="sh_distance_row">
# <td class="leftCol">
# <b>Distance:</b><br/>
# </td>
# <td>
# <b><span id="sh_distance"></span> miles</b>
# </td>
# </tr>
# <tr>
# <td align="right" colspan="2">
# <a href="#" id="sh_moredetails" style="float:right;font-weight:normal; font-size:85%" target="_top" title="More details">More Details</a>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <div class="jsSatView" id="mapViewSwitcher">
# <ul class="li-h li-h--pipe">
# <li><a href="#" id="jsSatView" title="Satellite View">Satellite</a></li>
# <li><a href="#" id="jsRoadView" title="Road View">Road</a></li>
# </ul>
# </div>
# <div class="map-controls" id="map-controls">
# <ul class="li-h li-h--subnav" role="presentation">
# <li aria-controls="ada-schoolsDropdown" aria-expanded="false" aria-label="Schools" class="dropdown-menu-parent js-map-control-schools dispBlock" role="link" tabindex="0">
#       Schools <i aria-hidden="true" class="icon--close-x-color icon-std-layout-right"></i>
# <div class="dropdown-menu-child hide-content" id="ada-schoolsDropdown">
# <ul class="li-v li-v--dropdown-menu" role="presentation">
# <li role="presentation">
# <input aria-checked="false" id="schoolCheckbox" name="schoolCheckbox" role="menuitemcheckbox" type="checkbox" value="1"/>
# <label for="schoolCheckbox">
# <i aria-hidden="true" class="f-icon f-icon-school school-rating-green"></i>
# <span class="v-align-mid">Schools</span>
# </label>
# </li>
# <li role="presentation">
# ...
# <use xlink:href="https://www.century21.com/z/20191108192240/images/icons/svg/symbol-defs.svg#icon--heart-full"></use>
# </svg>
#
#               Save</a>
# <a class="ml-5 btn-primary btn-primary--input btn-primary--large js-modals" href="/ac/boston/home_detail/cf_request_showing/pre_log/invoke.jsp?addressId=M-72594151-MLSPIN&amp;mlsNumber=72594151&amp;mlsSource=MLSPIN&amp;cta_location=hd-fixed-header&amp;bmd_company_id=2110" id="reqShowing" rel="nofollow">Request a Showing</a>
# </div>
# </div>
# </div>
# </div>
# <span class="js-recently-viewed-property" id="MLSPIN-72594151"></span>
# </div>
# <div class="l-fixed font-og">
# <div class="pt-20 pb-20 font-11">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         37-39 Cunard Street is a 20 bedroom, 6 bathroom Multi-Family home for sale in Boston, MA.
#
#           Currently listed for $5,250,000, this property features a 3,078 Sq. Ft. square foot lot and was built in 1900.
#
#
#          This listing is provided courtesy of BOSTON REALTY ADVISORS.
#         Want to view more homes for sale in Boston, MA? View all the latest MLS listings and explore photos, maps, schoolrankings,
#         real estate agent reviews, and more - all on CENTURY 21.
#
#
#
#
#
#
#
#
#
#
#     </div>
# </div>
# </main>
# <div id="ft">
# <footer class="js-external-loader">
# <div id="ftcontainer">
# <div class="footer-brand footer-top" id="century-footer">
# <div class="footer-sections">
# <div class="footer-logo">
# <!--company id: 2110, metro: boston, zip: 02120 , team id: null -->
# <!--zips: 02120 -->
# <!--counts: 1 -->
# <!--cartusBrokerOnTop: null -->
# <!--sessionId: 5245261361 -->
# <div class="broker-ftr cf l-fixed font-444 mb-20">
# <div class="f-left">
# <div class="smallVPad">
#       Local real estate services provided by:
#     </div>
# <div class="media">
# <div class="media__img media__img--stdmarg ft-brand-logo ft-brand-logo--2110">
# <img alt="CENTURY 21 Cityside" src="https://images.static-century21.com/images_broker/v3/C21/2110/Gold_Left_Aligned_Logo172x68.png" style="background-color:#fff; padding:10px;"/>
# </div>
# <div class="media__content">
# <span class="mls-company-name">CENTURY 21 Cityside</span><br/>
#
#         575 Boylston Street<br/>
#         Boston, MA 02116<br/>
# <br/>
# <div class="smallVPad">
# <i aria-hidden="true" class="f-icon f-icon-phone f-icon-1x"></i>
# <strong class="vmiddle font-15 footer-bottom--phone--MA" style="margin-left: 5px">
#
#             617.262.2600
#           </strong>
# </div>
# </div>
# </div>
# <div class="smallVPad">
#       Website provided and owned by CENTURY 21 Cityside.
#     </div>
# </div>
# </div>
# </div>
# <div class="footer-links">
# <h2 class="footer-links-header">General</h2>
# <ul>
# <li>
# <a href="/footer_pages/fair_housing.jsp">Fair Housing Act</a>
# <span aria-hidden="true" class="olb-separator">•</span>
# </li>
# <li>
# <a href="/employment-scam-alert">Fraud Alert</a>
# <span aria-hidden="true" class="olb-separator">•</span>
# </li>
# <li>
# <a href="/footer_pages/ada.jsp">Accessibility Statement</a>
# <span aria-hidden="true" class="olb-separator">•</span>
# </li>
# <li>
# <a href="/footer_pages/dmca.jsp">DMCA Notice</a>
# </li>
# </ul>
# <h2 class="footer-links-header">About CENTURY 21</h2>
# <ul class="footer-links">
# <li>
# <a href="/aboutus/companyprofile">Company Profile</a>
# <span aria-hidden="true" class="olb-separator">•</span>
# </li>
# <li>
# <a href="/aboutus">About Us</a>
# <span aria-hidden="true" class="olb-separator">•</span>
# </li>
# <li>
# <a href="/aboutus/mediacenter">In The News</a>
# <span aria-hidden="true" class="olb-separator">•</span>
# </li>
# <li>
# <a href="/aboutus/philanthropy">Philanthropy</a>
# <span aria-hidden="true" class="olb-separator">•</span>
# </li>
# <li>
# <a href="/real-estate-blog">Blog</a>
# </li>
# </ul>
# <h2 class="footer-links-header">Real Estate Resources</h2>
# <ul class="footer-links">
# <li>
# <a href="/home-selling-advice">Home Seller Resources</a>
# <span aria-hidden="true" class="olb-separator">•</span>
# </li>
# <li>
# <a href="/home-buying-advice">Home Buyer Resources</a>
# <span aria-hidden="true" class="olb-separator">•</span>
# </li>
# <li>
# <a href="/glossary">Real Estate Glossary</a>
# <span aria-hidden="true" class="olb-separator">•</span>
# </li>
# <li>
# <a href="/calculators/home-mortgage">Mortgage Calculators</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="footer-disclaimer">
# <div class="footer-row">
# <div class="footer-container">
# <div class="footer-disclaimer-wrap">
# <p class="legal-copy"></p>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-logo-seal">
# <a class="" href="/">Home</a>
# </div>
# </div>
# <div class="footer-bottom">
# <div class="footer-phone">
# <a class="cfDistrict footer-bottom--phone--MA" href="tel:617.262.2600">617.262.2600</a>
# </div>
# <div class="footer-links">
# <a href="/contactus" target="_blank">Contact Us</a>
# <a href="/about-us/about/faqs/buying-and-selling" target="_blank">FAQs</a>
# <a href="/footer_pages/site_map.jsp" target="_blank">Site Map</a>
# <a href="/century-21-cityside-2110c/privacy" target="_blank">Privacy</a>
# <a href="/century-21-cityside-2110c/terms_of_use" target="_blank">Terms &amp; Conditions</a>
# </div>
# <ul class="footer-social-links hide-list-bullets">
# <li><a class="footer-icon-facebook footer-icon" href="http://www.facebook.com/pages/CENTURY-21-Real-Estate-LLC/44054450913" onclick="logSocialOnly('fb', 'footer')" target="_blank">Facebook</a></li>
# <li><a class="footer-icon-twitter footer-icon" href="http://twitter.com/Century21" onclick="logSocialOnly('twitter', 'footer')" target="_blank">Twitter</a></li>
# <li><a class="footer-icon-youtube footer-icon" href="http://www.youtube.com/century21" onclick="logSocialOnly('youtube', 'footer')" target="_blank">Youtube</a></li>
# <li><a class="footer-icon-instagram footer-icon" href="http://instagram.com/century21" onclick="logSocialOnly('instagram', 'footer')" target="_blank">Instagram</a></li>
# </ul>
# </div>
# <img alt="" class="d-none" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1066597832/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# <img height="0" src="//bat.bing.com/action/0?ti=5202356&amp;Ver=2" style="display:none; visibility: hidden;" width="0"/>
# <img height="1" src="https://www.facebook.com/tr?id=1660237170895659&amp;ev=PageView&amp;noscript=1" width="1"/>
# </div>
# <script async="" defer="" src="https://js.static-century21.com/z/20191108192240/js/modules/global.min.js" type="text/javascript"></script>
# <script src="https://js.static-century21.com/z/20191108192240/js/footer-all.js" type="text/javascript"></script>
# <script type="text/javascript">
#     console.log("YUI LOADED"); // THIS IS ENABLED TO DETERMINE WHICH PAGES NEEDS YUI REMOVAL
#     YAHOO.util.Event.addListener("feedback_link", "click", function() { IFPC.show(_JSP_URL_PREFIX + "/feedback/index.jsp", 625, 550) });
#   </script>
# <script type="text/javascript">
#     if(document.getElementById('geolocate')) {
#       document.getElementById('geolocate').addEventListener('click', geolocate)
#     }
#   </script>
# <div id="searchform_tip_bubble">
# <div class="bd"></div>
# </div>
# <script type="text/javascript">
#   ga('set', 'dimension1', 'No - Open Site');
#
#   ga('set', 'dimension17', 'Open');
#
#
#   ga('set', 'dimension3', 'No');
#
#
#
#   ga('set', 'dimension4', 'boston');
#
#
#
#
#
#   ga('set', 'dimension7', 'web-opt');
#
#
#   ga('set', 'dimension12', '2110');
# ga('set', 'dimension28', '8f3aee33-bb54-42f0-9dfe-15c4d3a49787');
# ga('set', 'dimension30', '23a741e0-dd0b-4b67-b67d-acdc0ec2d0bc');
# ga('set', 'metric1', '5250000');
# ga('set', 'dimension5', 'For Sale');
#
# ga('set', 'dimension18', 'MLS-Photos-MLS-Description');
#
# ga('set', 'dimension26', 'Non-Brand');
#
#
#
#
#   ga('send', 'pageview');
#
#
#
#
#
# </script>
# <img alt="" class="d-none" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1071943691/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# <img height="1" src="https://www.facebook.com/tr?id=1657514467658870&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# <script type="text/javascript">
#   window.addEventListener('load',function() {
#     var Data = {
#         },i=Data,d=document,u=encodeURIComponent,x=z='',j=d.createElement('script'),
#         r=d.referrer,s=d.getElementsByTagName('script')[0];j.type='text/javascript';
#     j.async=!0;r&&r.split(/[/:?]/)[3]!=d.location.hostname&&(i.ref=r);for(y in i)
#       x+='&'+y+'='+u(i[y]);j.src='//com-ziprealty.netmng.com/'
#         +'?aid=3507&siclientid='+x;s.parentNode.insertBefore(j,s);
#   });
#
#
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "7705242" });
#   window.addEventListener('load',function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   });
#
# </script>
# <img height="1" src="https://www.facebook.com/tr?id=344959929184761&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# <img height="1" src="https://www.facebook.com/tr?id=514694242232515&amp;ev=PageView&amp;noscript=1" width="1"/>
# <zap-pageview-tracker data-application-id="8" data-company-id="2110" data-customer-id="" data-metro="boston" data-personnel-id="" data-uri="/longisland/property/37_39-Cunard-Street-Boston-MA-02120/M-72594151-MLSPIN/detail?src=list" data-wu-session-log-id="5245261361">
# </zap-pageview-tracker>
# </footer>
# </div>
# <script type="text/javascript">
#   Z.addOnLoadEventHandler(function() {
#     var fnCfg = new FixedPosNav({id: "fixedCTA", scrollPastElem: "hdCTA", coordPosAdjust: 160 });
#   });
# </script>
# <script language="Javascript" src="https://js.static-century21.com/z/20191108192240/js/mortgage_calc_new.js" type="text/javascript"></script>
# <div class="l-fixed mb-20 mt-20 legal-disclaimer font-a font-16" id="ftmlsdiscbox">
# </div>
# <script type="text/javascript">
#   function saveAddress(arrIds, addressId, companyId) {
#     ga('send', 'event', 'save_address', 'complete', '');
#     var success = function(o) {
#       var i = parseInt(o.responseText);
#       if(i == -1) {
#         alert("You must be a registered user to save homes.  Please register and try again."); // todo: overlay
#       } else if(i > 0) {
#         for(var c = 0; c < arrIds.length; c++){
#           var elem = document.getElementById(arrIds[c]);
#           if(elem) {
#             elem.innerHTML = '<i class="icon-btn icon-btn--watch"></i>Subscribed To Updates';
#             YAHOO.util.Dom.addClass(elem, "active btn-primary--disabled");
#             if(elem.href) {
#               //elem.href = _JSP_URL_PREFIX + "/account/my_homes/boston/detailed.jsp"; // todo: pass in the metro
#               elem.href = "javascript:void(0)";
#             }
#             //Add Tooltip container wrap
#             var tooltipTarget = document.getElementById("watch-cta").innerHTML;
#             var tooltipWrap = "<span class='tooltip tooltip--icon tooltip--top'>" + tooltipTarget + "<div class='tooltip__body tooltip__caret--bottom\'  style='margin-bottom:22px; left:5px; width:180px\'> Your watched homes are saved in \"<a class='m-0' href='/account/watched_homes/'><strong>Your Account</strong></a>\" at the top of the screen.</div></span>";
#             document.getElementById("watch-cta").innerHTML = tooltipWrap;
#           }
#         }
#       }
#       //alert("success: " + o.responseText);
#     };
#     var failure = function(o) {
#       //alert("failure: " + o.responseText);
#     };
#
#     var callback = {
#       success: success,
#       failure: failure
#     };
#     var url = '/xhr/saveAddress?addressId=' + addressId + '&companyId=' + companyId;
#     //  alert(url);
#     YAHOO.util.Connect.asyncRequest('POST', url, callback);
#   }
# </script>
# <script type="text/javascript">
#
#   function likeHome(id,  mlsNumber, mlsSource, companyId, isLike) {
#     ga('send', 'event', 'like_home', 'complete', '');
#
#     var success = function(o) {
#       var elem = document.getElementById(id);
#       if(elem) {
#         if(isLike) {
#           elem.innerHTML = parseInt(elem.innerHTML) + 1;
#         } else {
#           elem.innerHTML = parseInt(elem.innerHTML) - 1;
#         }
#       }
#       //alert("success: " + o.responseText);
#     };
#     var failure = function(o) {
#       //alert("failure: " + o.responseText);
#     };
#
#     var callback = {
#       success: success,
#       failure: failure
#     };
#     var url = '/xhr/likeHome?mlsNumber=' + mlsNumber + '&mlsSource=' + mlsSource + '&companyId=' + companyId + '&isLike=' + isLike;
#     //  alert(url);
#     YAHOO.util.Connect.asyncRequest('POST', url, callback);
#   }
#
#
#
#
# </script>
# <script src="https://js.static-century21.com/js/yui/yui-2.9.0/json/json-min.js" type="text/javascript"></script>
# <script src="https://js.static-century21.com/js/yui/yui-2.9.0/swf/swf-min.js" type="text/javascript"></script>
# <script src="https://js.static-century21.com/js/yui/yui-2.9.0/charts/charts-min.js" type="text/javascript"></script>
# <script src="https://js.static-century21.com/z/20191108192240/js/sales_trends_chart.js" type="text/javascript"></script>
# <script language="JavaScript" src="https://js.static-century21.com/z/20191108192240/js/imap/imap-all-min.js" type="text/javascript"></script>
# <script src="https://js.static-century21.com/z/20191108192240/js/imap/imap-google.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var showSaveNotePanel = function(mlsNumber, mlsSource) {
#     IFPC.show('/ac/boston/home_detail/rf_save_note/pre_log/invoke.jsp?cta_location=hd-note&mlsNumber=' + mlsNumber + "&mlsSource=" + mlsSource, 550, 500);
#   };
# </script>
# <script type="text/javascript">
#   (function loadListTrac() {
#     var s,
#         r,
#         t;
#     r = false;
#     s = document.createElement('script');
#     s.type = 'text/javascript';
#     s.async = true;
#     s.src = '//code.listtrac.com/monitor.ashx?acct=B_100597&nonjq=1';
#     s.onload = s.onreadystatechange = function () {
#       if (!r && (!this.readyState || this.readyState == 'complete')) {
#         r = true;
#         if (typeof(_LT) != 'undefined' && _LT != null) {
#           _LT._trackEvent(_eventType.view, '72594151'.replace(/_/g, '-'), '02120');
#         }
#       }
#     };
#     t = document.getElementsByTagName('script')[0];
#     t.parentNode.insertBefore(s, t);
#   })();
# </script>
# <script>
#   Z.addOnLoadEventHandler(function() {
#
#     if (location.href.indexOf("#expert-insights") != -1) {
#       setTimeout(function(){
#
#         smoothScroll('expert-insights');
#       }, 3000);
#     }
#     if (location.href.indexOf("#mortgagecalc") != -1) {
#       setTimeout(function(){
#
#         smoothScroll('mortgagecalc');
#       }, 3000);
#     }
#   });
# </script>
# <script async="" defer="" src="https://js.static-century21.com/z/20191108192240/js/modules/zapCharts.min.js" type="text/javascript"></script>
# <script type="application/ld+json">
# {
#   "@context": "http://www.schema.org",
#   "@type": "PostalAddress",
#
#   "streetAddress": "37-39 Cunard Street",
#   "addressLocality": "Boston",
#   "addressRegion": "MA",
#   "postalCode": "02120"
#
# }
# </script>
# <zap-market-info-request-overlay data-show-prompt="false" data-url="/ac/boston/home_detail/active_metro_prompt/pre_log/invoke.jsp?addressId=M-72594151-MLSPIN&amp;mlsNumber=72594151&amp;mlsSource=MLSPIN&amp;cta_location=hd-top&amp;bmd_company_id=2110" data-user="1620368929"></zap-market-info-request-overlay>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"errorBeacon":"bam.nr-data.net","licenseKey":"692b4306b8","agent":"","beacon":"bam.nr-data.net","applicationTime":234,"applicationID":"210614834","transactionName":"NAZaMksAWktTBhZZDg1MaxZLCFpfcQoMRBMMD1QDS05ZF0IXDUAEERdBSUIHQVReJAZUEwYQSxsWGlVcVhcHQxIqB0VJXQRAWVsJQhgmJjcR","queueTime":0}</script><script defer="" src="/zplabsdstlinj.js" type="text/javascript"></script><style type="text/css">#d__fFH{position:absolute;top:-5000px;left:-5000px}#d__fF{font-family:serif;font-size:200px;visibility:hidden}#fuyqtwbsbuscswtd{display:none!important}</style></body>
# </html>
